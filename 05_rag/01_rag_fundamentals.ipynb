# %% [markdown]
# # Module 05 — Notebook 01: RAG Fundamentals
#
# **RAG** = **Retrieval** (mencari potongan informasi relevan dari kumpulan dokumen) + **Augmented Generation** (LLM menyusun jawaban berdasarkan informasi tersebut). LLM tidak menjawab dari ingatannya saja, melainkan dibekali konteks faktual terlebih dahulu.
#
# ## Kenapa perlu RAG?
#
# LLM punya dua kelemahan utama:
#
# 1. **Halusinasi** — model mengarang jawaban yang terdengar meyakinkan tapi salah karena tidak punya akses ke fakta yang benar.
# 2. **Knowledge cutoff** — model tidak tahu kejadian setelah tanggal pelatihannya.
#
# RAG menambal keduanya dengan menyuntikkan konteks segar (dari knowledge base kita sendiri) pada setiap permintaan jawaban.
#
# ## Apa yang akan kita pelajari?
#
# | # | Komponen | Peran dalam RAG |
# |---|----------|-----------------|
# | 1 | Embedding (SentenceTransformer) | Mengubah teks → vektor |
# | 2 | Knowledge base | Sumber fakta yang bisa dicari |
# | 3 | FAISS index | Pencarian vektor cepat |
# | 4 | Generator (Qwen2.5-3B-Instruct, 4-bit) | Menyusun jawaban akhir |
# | 5 | Pipeline RAG | Retrieve → augment prompt → generate |
#
# ---

# %%
# !pip install -q "transformers<5" "sentence-transformers>=3.0" faiss-cpu accelerate bitsandbytes

# %%
import torch
import faiss
import numpy as np
from sentence_transformers import SentenceTransformer
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

# %% [markdown]
# ## 1. Embedding — Teks Menjadi Vektor
#
# **Embedding** adalah representasi numerik sebuah kalimat dalam ruang berdimensi tinggi. Kalimat yang bermakna mirip akan menghasilkan vektor yang letaknya berdekatan.
#
# Contoh sederhana:
# - *"Kucing itu berbulu"* ↔ *"Hewan itu punya bulu"* → vektor sangat dekat
# - *"Kucing itu berbulu"* ↔ *"Harga saham naik"* → vektor sangat jauh
#
# Kita menggunakan model **`paraphrase-multilingual-MiniLM-L12-v2`** karena:
# - Mendukung **50+ bahasa** termasuk Bahasa Indonesia dan Inggris.
# - Ringan (dimensi 384) sehingga cepat di-encode bahkan di CPU.
# - Cocok untuk knowledge base dan pertanyaan yang bercampur dua bahasa.

# %%
embedder = SentenceTransformer("sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2")
dim = embedder.get_sentence_embedding_dimension()  # 384
print(f"Embedding dimension: {dim}")

# %% [markdown]
# ## 2. Knowledge Base — Sumber Fakta
#
# **Knowledge base** adalah kumpulan fakta yang berfungsi sebagai sumber kebenaran bagi sistem RAG.
#
# Beberapa catatan:
# - Fakta dibuat **timeless** — tidak bergantung pada peristiwa politik atau tanggal tertentu yang bisa berubah. Ini penting agar notebook tetap valid kapan pun dijalankan.
# - Knowledge base di sini sengaja kecil agar mudah dipahami. Pada notebook berikutnya (nb02) kita akan menggunakan korpus nyata yang lebih besar.
# - Kita sengaja **tidak** memasukkan informasi tentang Cocos Island agar bisa menguji respons model ketika pertanyaan berada di **luar** knowledge base.
#
# > Knowledge base ini sengaja mencampur kalimat Bahasa Indonesia dan Inggris untuk menunjukkan bahwa model embedding multilingual menangani keduanya dalam satu ruang vektor.

# %%
knowledge_base = [
    "Menara Eiffel terletak di kota Paris, ibu kota Prancis.",
    "Bahasa pemrograman Python diciptakan oleh Guido van Rossum.",
    "Candi Borobudur berada di Magelang, Jawa Tengah, dan merupakan candi Buddha terbesar di dunia.",
    "The Great Wall of China is over 13,000 miles long.",
    "Fotosintesis adalah proses tumbuhan mengubah cahaya matahari menjadi energi.",
    "Komodo adalah kadal terbesar di dunia dan hidup di Indonesia.",
]
print(f"Knowledge base: {len(knowledge_base)} dokumen")

# %%
# Encode all documents and build a FAISS flat L2 index.
# Cosine similarity is introduced in nb05; we use L2 here to keep things simple.
kb_vectors = embedder.encode(knowledge_base, convert_to_numpy=True).astype("float32")
index = faiss.IndexFlatL2(dim)
index.add(kb_vectors)
print(f"Encoded {len(knowledge_base)} dokumen -> shape {kb_vectors.shape}; index berisi {index.ntotal} vektor")
print(f"FAISS index berisi {index.ntotal} vektor (dim={dim})")

# %% [markdown]
# ## 3. Generator — Qwen2.5-3B-Instruct (4-bit)
#
# Komponen **generator** adalah LLM yang menyusun jawaban akhir berdasarkan konteks yang sudah kita ambilkan.
#
# Model yang kita pakai: **Qwen/Qwen2.5-3B-Instruct**
# - 3 miliar parameter — cukup cerdas untuk QA faktual, jauh lebih ringan dari model 7B+.
# - **Tidak memerlukan akses terbatas** (non-gated), bisa diunduh langsung tanpa HF token khusus.
#
# Agar muat di GPU T4 (16 GB VRAM), model dimuat dengan **kuantisasi 4-bit** via `BitsAndBytesConfig`:
# - `load_in_4bit=True` — bobot model dikompres ke 4 bit.
# - `bnb_4bit_compute_dtype=torch.float16` — komputasi tetap di float16 (bukan bf16, karena T4 tidak mendukung bf16 native).
# - `bnb_4bit_quant_type="nf4"` + `bnb_4bit_use_double_quant=True` — teknik NF4 + double-quant untuk akurasi maksimal di bit rendah.
#
# > Catatan: unduhan model pertama kali sekitar 2 GB dan bisa memakan waktu 2–5 menit di Colab. Tunggu sampai sel selesai (tidak hang).

# %%
bnb = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True,
)
model_name = "Qwen/Qwen2.5-3B-Instruct"
tok = AutoTokenizer.from_pretrained(model_name)
gen = AutoModelForCausalLM.from_pretrained(model_name, quantization_config=bnb, device_map="auto")
print("Generator siap:", model_name)

# %% [markdown]
# ## 4. Pipeline RAG: Retrieve → Augment → Generate
#
# Pipeline tiga langkah:
#
# 1. **Retrieve** — embed pertanyaan, cari `k` dokumen terdekat di FAISS.
# 2. **Augment** — susun prompt dengan konteks dokumen yang ditemukan + pertanyaan asli.
# 3. **Generate** — LLM menghasilkan jawaban berdasarkan prompt yang diperkaya itu.
#
# ### Kenapa decoding deterministik?
#
# Untuk QA faktual kita menggunakan **greedy decoding** (`do_sample=False`), bukan sampling acak (`temperature`, `top_p`). Alasannya:
# - Sampling menghasilkan variasi jawaban yang kreatif, tapi juga rentan *"menduga-duga"* di luar konteks.
# - Greedy selalu memilih token dengan probabilitas tertinggi → jawaban lebih konsisten dan mengurangi halusinasi.
#
# Format prompt menggunakan `apply_chat_template` bawaan tokenizer sehingga template chat-nya selalu sesuai dengan model yang digunakan.

# %%
def retrieve(query, k=3):
    """Embed the query and return the top-k closest knowledge-base documents."""
    qv = embedder.encode([query], convert_to_numpy=True).astype("float32")
    dist, idx = index.search(qv, k)
    return [knowledge_base[i] for i in idx[0]], dist[0]


def ask(query, k=3):
    """Full RAG pipeline: retrieve → augment prompt → generate answer."""
    docs, dist = retrieve(query, k)
    context = "\n".join(f"- {d}" for d in docs)
    messages = [
        {"role": "system", "content": "Jawab HANYA berdasarkan konteks. Jika tidak ada di konteks, katakan tidak tahu."},
        {"role": "user", "content": f"Konteks:\n{context}\n\nPertanyaan: {query}"},
    ]
    prompt = tok.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
    inputs = tok(prompt, return_tensors="pt").to(gen.device)
    out = gen.generate(**inputs, max_new_tokens=128, do_sample=False)
    answer = tok.decode(out[0][inputs.input_ids.shape[1]:], skip_special_tokens=True)
    return answer.strip(), docs

# %% [markdown]
# ## 5. Uji Pipeline
#
# Kita akan menguji dua skenario:
#
# 1. **Pertanyaan yang ADA di knowledge base** — sistem harus menjawab dengan benar berdasarkan konteks.
# 2. **Pertanyaan yang TIDAK ADA di knowledge base** (*"Where is Cocos Island?"*) — sistem harus mengakui bahwa informasi tersebut tidak tersedia, bukan mengarang jawaban.
#
# Skenario kedua ini penting untuk memastikan **fallback behavior** bekerja: dengan instruksi sistem *"jawab HANYA berdasarkan konteks"*, model idealnya menjawab bahwa ia tidak tahu daripada berhalusinasi.

# %%
for q in ["Di mana letak Menara Eiffel?",
          "Siapa pencipta Python?",
          "Di mana Candi Borobudur?",
          "Where is Cocos Island?"]:   # <-- deliberately NOT in the KB
    ans, docs = ask(q)
    docs_str = "\n".join(f"   [{i+1}] {d}" for i, d in enumerate(docs))
    print(f"Q: {q}\nDokumen ditemukan:\n{docs_str}\nA: {ans}\n{'-'*50}")

# %% [markdown]
# ## Ringkasan
#
# Kita telah membangun sistem **RAG hello-world** dari nol dengan komponen berikut:
#
# | Komponen | Implementasi | Peran |
# |----------|-------------|-------|
# | Embedder | `paraphrase-multilingual-MiniLM-L12-v2` | Teks → vektor 384-dim, multilingual |
# | Index kemiripan | `faiss.IndexFlatL2` | Pencarian L2 brute-force |
# | Generator | `Qwen2.5-3B-Instruct` (4-bit NF4) | Jawaban grounded, deterministik |
# | Prompt builder | `apply_chat_template` | Template chat resmi model |
# | Decoding | `do_sample=False` (greedy) | Mengurangi halusinasi pada QA faktual |
#
# ### Langkah selanjutnya
#
# - **Notebook 02** — `02_ingest_and_chunk.ipynb`: ingest dokumen PDF nyata, chunking teks dengan strategi sentence/fixed/semantic.
# - **Notebook 05** — perbandingan metrik kemiripan: cosine vs L2 — kapan masing-masing lebih baik?
#
# ---
#
# > **Catatan**: Notebook ini dirancang untuk Google Colab dengan GPU T4 (16 GB). Jalankan *Runtime → Change runtime type → T4 GPU* sebelum memulai.
