# %% [markdown]
# # 📚 Module 04: Dasar Large Language Models (LLM)
#
# **LLM** (**Large Language Model**) adalah jenis model **NLP** (**Natural Language Processing**) yang dilatih pada data teks dalam jumlah masif, sehingga mampu memahami konteks dan menghasilkan teks mirip tulisan manusia. LLM hampir selalu dibangun di atas arsitektur **transformer**.
#
# **NLP vs LLM:**
# - **Scope (cakupan):** **NLP** adalah bidang luas (klasifikasi teks, terjemahan, dll), sedangkan **LLM** adalah satu jenis model di dalam NLP.
# - **Data:** LLM dilatih pada dataset jauh lebih besar daripada model NLP tradisional.
# - **Kemampuan:** LLM unggul dalam generasi teks, memahami konteks, dan percakapan terbuka (mis. **chatbot**).
#
# ## Apa yang akan kita pelajari?
# 1. **LLM inference** dengan model kecil (`facebook/opt-350m`)
# 2. Dua cara memakai model HuggingFace: **`pipeline`** (cepat) vs memuat `AutoModel` + `AutoTokenizer` (manual)
# 3. **Text classification** dengan model transformer
# 4. Membuat **chatbot** sederhana dengan **Gradio**
# 5. **Few-shot learning** lewat prompt
# 6. **Model evaluation** sederhana
#
# ---

# %%
# First, ensure GPU is available
# !nvidia-smi
# Out:
# Thu Jun 11 10:40:23 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   54C    P8             12W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# Install required packages
# PENTING: pin transformers < 5. Colab kini membawa transformers v5 yang
# memecah API lama (apply_chat_template) & tokenizer model kecil (bert-tiny).
# Versi 4.x stabil membuat seluruh notebook ini jalan sesuai materi.
# Jika kamu menjalankan ulang setelah sempat memakai v5: Runtime -> Restart session,
# lalu Run all dari atas agar versi 4.x benar-benar terpakai.
# !uv pip install -q "transformers>=4.44,<5" datasets evaluate accelerate bitsandbytes sentencepiece
# !uv pip install -q gradio

# %%
import torch
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    pipeline,
    AutoModelForSequenceClassification,
)
import gradio as gr

# %%
print("GPU Available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU Name:", torch.cuda.get_device_name(0))
# Out:
# GPU Available: True
# GPU Name: Tesla T4

# %% [markdown]
# ## 1. LLM Inference dengan Model Kecil
#
# **LLM inference** = proses memakai model yang sudah dilatih untuk menghasilkan teks dari sebuah **prompt** (teks masukan).
#
# Kita pakai **`facebook/opt-350m`** lewat `AutoModelForCausalLM` + `AutoTokenizer`:
# - `torch_dtype=torch.float16` -> bobot disimpan 16-bit agar **hemat memori GPU** (cukup untuk Tesla T4).
# - `device_map="auto"` -> otomatis menaruh model di GPU bila tersedia.
# - `temperature=0.7` & `do_sample=True` -> membuat output lebih bervariasi (tidak selalu sama).

# %%
# 1. Basic LLM Inference using smaller models
print("\n1. Basic LLM Inference")

def initialize_model(model_name="facebook/opt-350m"):
    """Initialize model and tokenizer"""
    print(f"Loading {model_name}...")
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForCausalLM.from_pretrained(
        model_name,
        device_map="auto",
        torch_dtype=torch.float16
    )
    return model, tokenizer

def generate_text(prompt, model, tokenizer, max_length=100):
    """Generate text using the model"""
    # Pakai device milik model (bukan hardcode "cuda") agar tetap aman bila di CPU
    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
    outputs = model.generate(
        **inputs,
        max_length=max_length,
        num_return_sequences=1,
        temperature=0.7,
        do_sample=True,
        pad_token_id=tokenizer.eos_token_id  # hindari warning pad_token saat generate
    )
    return tokenizer.decode(outputs[0], skip_special_tokens=True)
# Out:
# 1. Basic LLM Inference

# %%
# Initialize small model for basic tasks
model, tokenizer = initialize_model()
# Out:
# Loading facebook/opt-350m...
# tokenizer_config.json:   0%|          | 0.00/685 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/644 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/441 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# pytorch_model.bin:   0%|          | 0.00/663M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]

# %%
# Test basic generation
prompt = "Explain what a large language model is:"
print("\nPrompt:", prompt)
print("Generated Response:", generate_text(prompt, model, tokenizer))
# Out:
# Prompt: Explain what a large language model is:
# model.safetensors:   0%|          | 0.00/662M [00:00<?, ?B/s]
# Generated Response: Explain what a large language model is:
#
# A large language model is a set of rules that describe how a language behaves.
#
# A large language model can be a dictionary of rules. But it is not a set of rules.
#
# A large language model is not a set of rules.
#
# A large language model can be a dictionary of functions. But it is not a set of functions.
#
# A large language model is not a set of rules.

# %% [markdown]
# ## 2. `pipeline` vs Memuat Model Manual
#
# Ada dua cara memakai model HuggingFace:
# - **`pipeline`** -> cara cepat & ringkas, cukup sebut task (`"text-generation"`) dan nama model.
# - **`AutoModel` + `AutoTokenizer`** -> memuat model secara manual, lebih fleksibel untuk mengatur tokenisasi & generasi sendiri.
#
# Di sini kita pakai model chat kecil **`TinyLlama/TinyLlama-1.1B-Chat-v1.0`** — bersifat **open** (tidak gated) dan ringan (~1,1 miliar parameter, `float16` ~2 GB), sehingga **benar-benar bisa dijalankan di Colab T4**.
#
# > **Catatan — model gated:** sebagian model populer bersifat **gated**, mis. **`meta-llama/Llama-2-7b-chat-hf`** dari Meta. Untuk memakainya kamu harus **menyetujui lisensi** di halaman model lalu **login HuggingFace** (`huggingface-cli login`) dengan token. Selain itu Llama-2-7B `float16` butuh ~14 GB memori (mepet untuk T4), jadi di kelas ini kita cukup memahaminya sebagai **konsep** dan memakai TinyLlama untuk demonya.

# %%
# (Opsional) Login HuggingFace — HANYA perlu untuk model GATED seperti Llama-2.
# TinyLlama di bawah bersifat open/non-gated, jadi langkah ini boleh dilewati.
# Jika suatu saat memakai model gated, aktifkan baris berikut lalu masukkan token:
# !huggingface-cli login
print("TinyLlama bersifat open — tidak perlu login HuggingFace untuk demo ini.")
# Out:
# TinyLlama bersifat open — tidak perlu login HuggingFace untuk demo ini.

# %%
# Cara 1 — pipeline (high-level helper): cukup sebut task + nama model
from transformers import pipeline

chat_model_name = "TinyLlama/TinyLlama-1.1B-Chat-v1.0"

chat_pipe = pipeline(
    "text-generation",
    model=chat_model_name,
    torch_dtype=torch.float16,
    device_map="auto",
)

messages = [
    {"role": "user", "content": "Who are you?"},
]
# pipeline otomatis menerapkan chat template milik model
output = chat_pipe(messages, max_new_tokens=100, do_sample=True, temperature=0.7)
print(output[0]["generated_text"])
# Out:
# config.json:   0%|          | 0.00/608 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors:   0%|          | 0.00/2.20G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/551 [00:00<?, ?B/s]
# Device set to use cuda:0
# [{'role': 'user', 'content': 'Who are you?'}, {'role': 'assistant', 'content': 'I am not a person. I am a machine that processes and interprets human speech, and is commonly used in speech recognition and natural language processing (nlp) technologies.'}]

# %%
# Cara 2 — load manual: kontrol penuh atas tokenizer & generate
from transformers import AutoTokenizer, AutoModelForCausalLM

# Catatan: pakai nama variabel terpisah (chat_*) agar TIDAK menimpa
# `model`/`tokenizer` (opt-350m) yang dipakai chatbot, few-shot & evaluasi di bawah.
chat_tokenizer = AutoTokenizer.from_pretrained(chat_model_name)
chat_model = AutoModelForCausalLM.from_pretrained(
    chat_model_name,
    torch_dtype=torch.float16,
    device_map="auto",
)

messages = [
    {"role": "user", "content": "Who are you?"},
]
# Terapkan chat template -> dict {input_ids, attention_mask}, lalu generate manual.
# return_dict=True + generate(**inputs) = pola robust lintas-versi transformers
# (versi baru mengembalikan BatchEncoding, bukan tensor polos).
inputs = chat_tokenizer.apply_chat_template(
    messages,
    add_generation_prompt=True,
    return_tensors="pt",
    return_dict=True,
).to(chat_model.device)
outputs = chat_model.generate(**inputs, max_new_tokens=100, do_sample=True, temperature=0.7)
print(chat_tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# <|user|>
# Who are you?
# <|assistant|>
# I am not capable of speaking or having a physical body. However, I can provide information and answer questions. My purpose in existence is to gather and process data, analyze them, and provide insights and explanations. I exist to answer questions, solve problems, and provide insights for my users to make informed decisions.
#
# so, who are you? you are the user who is asking me these questions and requesting my services. without you, I would not exist.

# %% [markdown]
# ## 3. Text Classification dengan Transformer
#
# **Text classification** = memberi label pada teks, misalnya menentukan **sentimen** (positif/negatif). Tiap teks menghasilkan `label` (kelas) dan `score` (keyakinan 0-1).
#
# Kita bandingkan **dua** model lewat `pipeline("sentiment-analysis")`:
#
# 1. **`prajjwal1/bert-tiny`** — model ini **baru di-pretrain** dan **belum punya head klasifikasi terlatih**. Akibatnya label keluar `LABEL_0`/`LABEL_1` dengan score ~0.5 (pada dasarnya **tebakan acak**). Sengaja kita tunjukkan agar paham: *arsitektur klasifikasi saja tidak cukup — head-nya harus dilatih (fine-tuned) dulu.*
# 2. **`distilbert-base-uncased-finetuned-sst-2-english`** — sudah **fine-tuned** untuk sentimen pada dataset **SST-2**, jadi labelnya bermakna (`POSITIVE`/`NEGATIVE`) dengan score yang meyakinkan.
#
# Perhatikan bedanya pada teks yang sama.

# %%
# 3. Text Classification with Transformer Models
print("\n3. Text Classification Example")

texts = [
    "I love working with language models!",
    "This task is quite challenging.",
    "The results are impressive and amazing."
]

# (a) bert-tiny: dibungkus manual lewat AutoModelForSequenceClassification.
#     Head klasifikasi BELUM dilatih -> LABEL_0/LABEL_1, score ~0.5 (tebakan acak).
bt_tokenizer = AutoTokenizer.from_pretrained("prajjwal1/bert-tiny")
bt_model = AutoModelForSequenceClassification.from_pretrained("prajjwal1/bert-tiny")
clf_untrained = pipeline("sentiment-analysis", model=bt_model, tokenizer=bt_tokenizer,
                         device=0 if torch.cuda.is_available() else -1)

# (b) distilbert SST-2: sudah fine-tuned -> POSITIVE/NEGATIVE yang bermakna.
clf_finetuned = pipeline("sentiment-analysis",
                         model="distilbert-base-uncased-finetuned-sst-2-english",
                         device=0 if torch.cuda.is_available() else -1)

for label, clf in [("Belum fine-tuned (bert-tiny)", clf_untrained),
                   ("Sudah fine-tuned (distilbert SST-2)", clf_finetuned)]:
    print(f"\n=== {label} ===")
    for text in texts:
        r = clf(text)[0]
        print(f"  {r['label']:<9} score={r['score']:.3f}  | {text}")
# Out:
# 3. Text Classification Example
# config.json:   0%|          | 0.00/285 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/17.8M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at prajjwal1/bert-tiny and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Device set to use cuda:0
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/17.7M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# Device set to use cuda:0
# === Belum fine-tuned (bert-tiny) ===
#   LABEL_1   score=0.509  | I love working with language models!
#   LABEL_1   score=0.550  | This task is quite challenging.
# ...

# %% [markdown]
# ## 4. Chatbot Sederhana
#
# **Chatbot** sederhana di sini mengubah tiap pesan pengguna menjadi **prompt**, lalu model membalas; **Gradio** yang mengelola riwayat percakapan.
#
# Kita pakai `gr.ChatInterface` untuk membuat antarmuka chat:
# - Fungsi `chatbot_response` menyusun prompt `"User: ...\nAssistant:"` lalu memanggil `generate_text`.
# - `iface.launch(share=True)` membuat tautan publik agar chatbot bisa dicoba di browser.

# %%
# 4. Creating a Simple Chatbot Interface
print("\n4. Simple Chatbot Interface")

def chatbot_response(message, history):
    """Generate chatbot response"""
    prompt = f"User: {message}\nAssistant:"
    response = generate_text(prompt, model, tokenizer, max_length=150)
    return response

# Create Gradio interface
iface = gr.ChatInterface(
    chatbot_response,
    title="Simple LLM Chatbot",
    description="A basic chatbot using a small language model"
)

# Launch the interface
iface.launch(share=True)
# Out:
# 4. Simple Chatbot Interface
# /usr/local/lib/python3.12/dist-packages/gradio/chat_interface.py:347: UserWarning: The 'tuples' format for chatbot messages is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style 'role' and 'content' keys.
#   self.chatbot = Chatbot(
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://b4cb54e79db510e7a3.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://b4cb54e79db510e7a3.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## 5. Few-shot Learning
#
# **Few-shot learning** = memberi model beberapa **contoh** langsung di dalam prompt, tanpa melatih ulang model.
#
# Di sini kita beri 2 contoh pasangan tanya-jawab (ibu kota Prancis & Jepang), lalu model diminta melanjutkan pola tersebut untuk pertanyaan ke-3:
# - Karena prompt jadi lebih panjang, `max_length` dinaikkan agar jawaban tidak terpotong.
# - Model "belajar" pola dari contoh, bukan dari proses training.

# %%
# 5. Few-shot Learning Example
print("\n5. Few-shot Learning Example")

few_shot_prompt = """
Question: What is the capital of France?
Answer: The capital of France is Paris.

Question: What is the capital of Japan?
Answer: The capital of Japan is Tokyo.

Question: What is the capital of Italy?
Answer: """

print("Few-shot learning response:")
# Increase max_length to accommodate the prompt length or reduce the prompt length
print(generate_text(few_shot_prompt, model, tokenizer, max_length=100)) # Increased max_length to 100
# Out:
# 5. Few-shot Learning Example
# Few-shot learning response:
#
# Question: What is the capital of France?
# Answer: The capital of France is Paris.
#
# Question: What is the capital of Japan?
# Answer: The capital of Japan is Tokyo.
#
# Question: What is the capital of Italy?
# Answer:

# %% [markdown]
# ## 6. Model Evaluation
#
# **Model evaluation** = mengukur kualitas teks yang dihasilkan model agar kita tahu seberapa baik performanya.
#
# Fungsi `evaluate_model` menjalankan beberapa **test prompt** lalu mencatat:
# - `prompt` -> teks masukan
# - `response` -> teks hasil generasi
# - `length` -> jumlah kata pada respons (`len(response.split())`) sebagai metrik sederhana.

# %%
# 6. Model Evaluation
print("\n6. Model Evaluation")

def evaluate_model(model, tokenizer, test_prompts):
    """Basic model evaluation"""
    results = []
    for prompt in test_prompts:
        response = generate_text(prompt, model, tokenizer)
        results.append({
            'prompt': prompt,
            'response': response,
            'length': len(response.split())
        })
    return results

test_prompts = [
    "Explain how a computer works:",
    "Write a short poem about technology:",
    "List three benefits of artificial intelligence:"
]

evaluation_results = evaluate_model(model, tokenizer, test_prompts)
print("\nModel Evaluation Results:")
for result in evaluation_results:
    print(f"\nPrompt: {result['prompt']}")
    print(f"Response: {result['response']}")
    print(f"Response length: {result['length']} words")
# Out:
# 6. Model Evaluation
#
# Model Evaluation Results:
#
# Prompt: Explain how a computer works:
# Response: Explain how a computer works: why is it so difficult for a kid to understand?
# It's not that difficult.  If you have a computer with a software program running, you can actually do basic stuff.  You are just better at programming.
# I'm pretty sure you have too much free time on your hands to have to explain, but I agree. Computer programming can be a lot of work and the most time you have is spent on simple things.
# Response length: 79 words
#
# Prompt: Write a short poem about technology:
# Response: Write a short poem about technology:
#
# ...

# %%
print("""
Tips for Working with LLMs in Colab:
1. Always check GPU availability and memory usage
2. Use quantization for larger models
3. Be mindful of token limits and batch sizes
4. Consider using smaller models for experimentation
5. Save and load model checkpoints carefully

Exercises:
1. Try different prompts and parameters
2. Experiment with temperature and max_length
3. Test few-shot learning with different examples
4. Create custom evaluation metrics
5. Try different model architectures
""")
# Out:
# Tips for Working with LLMs in Colab:
# 1. Always check GPU availability and memory usage
# 2. Use quantization for larger models
# 3. Be mindful of token limits and batch sizes
# 4. Consider using smaller models for experimentation
# 5. Save and load model checkpoints carefully
#
# Exercises:
# 1. Try different prompts and parameters
# 2. Experiment with temperature and max_length
# 3. Test few-shot learning with different examples
# 4. Create custom evaluation metrics
# 5. Try different model architectures

# %% [markdown]
# ## Ringkasan
#
# Kita sudah belajar cara memakai **LLM** dengan HuggingFace transformers: dari inference model kecil, klasifikasi teks, chatbot, hingga few-shot learning dan evaluasi.
#
# | # | Topik | Library | Tujuan |
# |---|-------|---------|--------|
# | 1 | LLM inference | transformers (`facebook/opt-350m`) | Generasi teks dari prompt, hemat memori dengan float16 |
# | 2 | `pipeline` vs manual | transformers, huggingface_hub | Dua cara memakai model (cepat vs fleksibel) |
# | 3 | Text classification | transformers (`prajjwal1/bert-tiny`) | Klasifikasi sentimen teks |
# | 4 | Chatbot | Gradio | Antarmuka percakapan sederhana |
# | 5 | Few-shot learning | transformers | Belajar dari contoh dalam prompt |
# | 6 | Model evaluation | transformers | Mengukur kualitas output generasi |
#
# **Langkah selanjutnya**: lanjut ke **Module 05: Retrieval-Augmented Generation (RAG)**.
